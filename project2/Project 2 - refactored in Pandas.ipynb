# %%
import pandas as pd
# %matplotlib inline
pd.set_option("max_columns", 150)
pd.set_option('max_colwidth',40)
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# open the Master.csv and Salaries.csv tables

# %%
master = pd.read_csv('Master.csv') # File with player details
salary = pd.read_csv('Salaries.csv') #File with baseball players' salaries

# %% [markdown]
# check to what type each item is with `print(table)`

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18846 entries, 0 to 18845
# Data columns (total 24 columns):
# playerID        18846 non-null object
# birthYear       18703 non-null float64
# birthMonth      18531 non-null float64
# birthDay        18382 non-null float64
# birthCountry    18773 non-null object
# birthState      18220 non-null object
# birthCity       18647 non-null object
# deathYear       9336 non-null float64
# deathMonth      9335 non-null float64
# deathDay        9334 non-null float64
# deathCountry    9329 non-null object
# deathState      9277 non-null object
# deathCity       9325 non-null object
# nameFirst       18807 non-null object
# nameLast        18846 non-null object
# nameGiven       18807 non-null object
# weight          17975 non-null float64
# height          18041 non-null float64
# bats            17655 non-null object
# throws          17868 non-null object
# debut           18653 non-null object
# finalGame       18653 non-null object
# retroID         18792 non-null object
# bbrefID         18845 non-null object
# dtypes: float64(8), object(16)
# memory usage: 3.5+ MB

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25575 entries, 0 to 25574
# Data columns (total 5 columns):
# yearID      25575 non-null int64
# teamID      25575 non-null object
# lgID        25575 non-null object
# playerID    25575 non-null object
# salary      25575 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 999.1+ KB

# %% [markdown]
# print out sample data with `table.head()`<br>
# see additional options by pressing `ctrl + tab` over the `head()` method

# %%
master.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01   1,981.00       12.00     27.00          USA         CO
# 1  aaronha01   1,934.00        2.00      5.00          USA         AL
# 2  aaronto01   1,939.00        8.00      5.00          USA         AL
# 3   aasedo01   1,954.00        9.00      8.00          USA         CA
# 4   abadan01   1,972.00        8.00     25.00          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay deathCountry deathState  \
# 0      Denver        nan         nan       nan          NaN        NaN
# 1      Mobile        nan         nan       nan          NaN        NaN
# 2      Mobile   1,984.00        8.00     16.00          USA         GA
# 3      Orange        nan         nan       nan          NaN        NaN
# 4  Palm Beach        nan         nan       nan          NaN        NaN
#
#   deathCity nameFirst nameLast       nameGiven  weight  height bats throws  \
# 0       NaN     David  Aardsma     David Allan  220.00   75.00    R      R
# 1       NaN      Hank    Aaron     Henry Louis  180.00   72.00    R      R
# 2   Atlanta    Tommie    Aaron      Tommie Lee  190.00   75.00    R      R
# 3       NaN       Don     Aase  Donald William  190.00   75.00    R      R
# 4       NaN      Andy     Abad   Fausto Andres  184.00   73.00    L      L
#
#         debut   finalGame   retroID    bbrefID
# 0  2004-04-06  2015-08-23  aardd001  aardsda01
# 1  1954-04-13  1976-10-03  aaroh101  aaronha01
# 2  1962-04-10  1971-09-26  aarot101  aaronto01
# 3  1977-07-26  1990-10-03  aased001   aasedo01
# 4  2001-09-10  2006-04-13  abada001   abadan01

# %%
salary.head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %% [markdown]
# Now we join the two csv's using `pd.merge`.<br>
# We want to keep all the players names in the `master` data set<br>
# even if their salary is missing from the `salary` data set.<br>
# We can always filter the NaN values out later

# %%
joined = pd.merge(left=master, right=salary, how="left")

# %% [markdown]
# see what columns the `joined` table contains

# %%
joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39455 entries, 0 to 39454
# Data columns (total 28 columns):
# playerID        39455 non-null object
# birthYear       39312 non-null float64
# birthMonth      39140 non-null float64
# birthDay        38991 non-null float64
# birthCountry    39382 non-null object
# birthState      37738 non-null object
# birthCity       39228 non-null object
# deathYear       9669 non-null float64
# deathMonth      9668 non-null float64
# deathDay        9667 non-null float64
# deathCountry    9662 non-null object
# deathState      9603 non-null object
# deathCity       9658 non-null object
# nameFirst       39416 non-null object
# nameLast        39455 non-null object
# nameGiven       39416 non-null object
# weight          38584 non-null float64
# height          38650 non-null float64
# bats            38264 non-null object
# throws          38477 non-null object
# debut           39262 non-null object
# finalGame       39262 non-null object
# retroID         39401 non-null object
# bbrefID         39454 non-null object
# yearID          25567 non-null float64
# teamID          25567 non-null object
# lgID            25567 non-null object
# salary          25567 non-null float64
# dtypes: float64(10), object(18)
# memory usage: 8.7+ MB

# %% [markdown]
# check if all the players have a salary assigned. The easiest way is to deduct the length of the `joined` table from the `master` table

# %%
len(master) - len(joined)
# Out:
# -20609

# %% [markdown]
# Something went wrong. There are now more players in the `joined` data set than in the `master` data set.<br>
# Some entries probably got duplicated<br>
# Let's check if we have duplicate `playerIDs` by using `.value_counts()`

# %%
joined["playerID"].value_counts()
# Out:
# moyerja01    25
# vizquom01    24
# glavito02    23
# thomeji01    22
# bondsba01    22
# griffke02    22
# maddugr01    21
# johnsra05    21
# clemero02    21
# rodrial01    21
# gordoto01    21
# smoltjo01    21
# sheffga01    21
# francjo01    21
# rhodear01    20
# rogerke01    20
# oliveda02    20
# rodriiv01    20
# wellsda01    20
# hawkila01    20
# jonesch06    20
# francju01    19
# jeterde01    19
# giambja01    19
# ramirma02    19
# gaettga01    19
# biggicr01    19
# larkiba01    19
# santibe01    19
# riverma01    19
#              ..
# schulha01     1
# romoen01      1
# smithkl01     1
# cruziv01      1
# colcoto01     1
# baislje01     1
# mcmilto01     1
# fisheed02     1
# slaybbi01     1
# diazja01      1
# ryderto01     1
# hamando01     1
# sampske01     1
# sallesl01     1
# johnsro02     1
# raudmbo01     1
# anderja01     1
# vinesbo01     1
# martist01     1
# ostrobr01     1
# mcanaji01     1
# sandeke01     1
# kirscha01     1
# langedi01     1
# matrada01     1
# abadan01      1
# powervi01     1
# adamsgl01     1
# bradfla01     1
# proctre01     1
# Name: playerID, dtype: int64

# %% [markdown]
# Yep, we do.<br>
# Let's filter out an arbitrary player to see why there is duplication

# %%
joined[joined["playerID"] == "moyerja01"]
# Out:
#         playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 24836  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24837  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24838  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24839  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24840  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24841  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24842  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24843  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24844  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24845  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24846  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24847  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24848  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24849  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24850  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24851  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24852  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24853  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24854  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24855  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24856  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24857  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24858  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24859  moyerja01   1,962.00       11.00     18.00          USA         PA
# 24860  moyerja01   1,962.00       11.00     18.00          USA         PA
#
#           birthCity  deathYear  deathMonth  deathDay deathCountry deathState  \
# 24836  Sellersville        nan         nan       nan          NaN        NaN
# 24837  Sellersville        nan         nan       nan          NaN        NaN
# 24838  Sellersville        nan         nan       nan          NaN        NaN
# 24839  Sellersville        nan         nan       nan          NaN        NaN
# 24840  Sellersville        nan         nan       nan          NaN        NaN
# 24841  Sellersville        nan         nan       nan          NaN        NaN
# 24842  Sellersville        nan         nan       nan          NaN        NaN
# 24843  Sellersville        nan         nan       nan          NaN        NaN
# 24844  Sellersville        nan         nan       nan          NaN        NaN
# 24845  Sellersville        nan         nan       nan          NaN        NaN
# 24846  Sellersville        nan         nan       nan          NaN        NaN
# 24847  Sellersville        nan         nan       nan          NaN        NaN
# 24848  Sellersville        nan         nan       nan          NaN        NaN
# 24849  Sellersville        nan         nan       nan          NaN        NaN
# 24850  Sellersville        nan         nan       nan          NaN        NaN
# 24851  Sellersville        nan         nan       nan          NaN        NaN
# 24852  Sellersville        nan         nan       nan          NaN        NaN
# 24853  Sellersville        nan         nan       nan          NaN        NaN
# 24854  Sellersville        nan         nan       nan          NaN        NaN
# 24855  Sellersville        nan         nan       nan          NaN        NaN
# 24856  Sellersville        nan         nan       nan          NaN        NaN
# 24857  Sellersville        nan         nan       nan          NaN        NaN
# 24858  Sellersville        nan         nan       nan          NaN        NaN
# 24859  Sellersville        nan         nan       nan          NaN        NaN
# 24860  Sellersville        nan         nan       nan          NaN        NaN
#
#       deathCity nameFirst nameLast nameGiven  weight  height bats throws  \
# 24836       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24837       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24838       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24839       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24840       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24841       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24842       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24843       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24844       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24845       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24846       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24847       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24848       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24849       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24850       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24851       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24852       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24853       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24854       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24855       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24856       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24857       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24858       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24859       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
# 24860       NaN     Jamie    Moyer     Jamie  170.00   72.00    L      L
#
#             debut   finalGame   retroID    bbrefID   yearID teamID lgID  \
# 24836  1986-06-16  2012-05-27  moyej001  moyerja01 1,986.00    CHN   NL
# 24837  1986-06-16  2012-05-27  moyej001  moyerja01 1,987.00    CHN   NL
# 24838  1986-06-16  2012-05-27  moyej001  moyerja01 1,988.00    CHN   NL
# 24839  1986-06-16  2012-05-27  moyej001  moyerja01 1,989.00    TEX   AL
# 24840  1986-06-16  2012-05-27  moyej001  moyerja01 1,990.00    TEX   AL
# 24841  1986-06-16  2012-05-27  moyej001  moyerja01 1,991.00    SLN   NL
# 24842  1986-06-16  2012-05-27  moyej001  moyerja01 1,993.00    BAL   AL
# 24843  1986-06-16  2012-05-27  moyej001  moyerja01 1,994.00    BAL   AL
# 24844  1986-06-16  2012-05-27  moyej001  moyerja01 1,995.00    BAL   AL
# 24845  1986-06-16  2012-05-27  moyej001  moyerja01 1,996.00    BOS   AL
# 24846  1986-06-16  2012-05-27  moyej001  moyerja01 1,997.00    SEA   AL
# 24847  1986-06-16  2012-05-27  moyej001  moyerja01 1,998.00    SEA   AL
# 24848  1986-06-16  2012-05-27  moyej001  moyerja01 1,999.00    SEA   AL
# 24849  1986-06-16  2012-05-27  moyej001  moyerja01 2,000.00    SEA   AL
# 24850  1986-06-16  2012-05-27  moyej001  moyerja01 2,001.00    SEA   AL
# 24851  1986-06-16  2012-05-27  moyej001  moyerja01 2,002.00    SEA   AL
# 24852  1986-06-16  2012-05-27  moyej001  moyerja01 2,003.00    SEA   AL
# 24853  1986-06-16  2012-05-27  moyej001  moyerja01 2,004.00    SEA   AL
# 24854  1986-06-16  2012-05-27  moyej001  moyerja01 2,005.00    SEA   AL
# 24855  1986-06-16  2012-05-27  moyej001  moyerja01 2,006.00    SEA   AL
# 24856  1986-06-16  2012-05-27  moyej001  moyerja01 2,007.00    PHI   NL
# 24857  1986-06-16  2012-05-27  moyej001  moyerja01 2,008.00    PHI   NL
# 24858  1986-06-16  2012-05-27  moyej001  moyerja01 2,009.00    PHI   NL
# 24859  1986-06-16  2012-05-27  moyej001  moyerja01 2,010.00    PHI   NL
# 24860  1986-06-16  2012-05-27  moyej001  moyerja01 2,012.00    COL   NL
#
#             salary
# 24836    60,000.00
# 24837    70,000.00
# 24838   142,500.00
# 24839   205,000.00
# 24840   340,000.00
# 24841   200,000.00
# 24842   200,000.00
# 24843   725,000.00
# 24844 1,100,000.00
# 24845   825,000.00
# 24846 1,700,000.00
# 24847 2,000,000.00
# 24848 2,300,000.00
# 24849 6,000,000.00
# 24850 6,500,000.00
# 24851 6,500,000.00
# 24852 6,500,000.00
# 24853 7,000,000.00
# 24854 8,000,000.00
# 24855 5,500,000.00
# 24856 6,500,000.00
# 24857 6,000,000.00
# 24858 6,500,000.00
# 24859 8,000,000.00
# 24860 1,100,000.00

# %% [markdown]
# As we can see, there are now salaries in the dataset for each year of the players carreer.<br>
# We only want to have the most recent salary though.<br>
# We therefore need to 'deduplicate' the data set.

# %%
deduplicated = joined.drop_duplicates("playerID", keep="last")

# %% [markdown]
# And let's do the check again

# %%
len(master) - len(deduplicated)
# Out:
# 0

# %% [markdown]
# Now we van get into the interesting part: analysis!

# %% [markdown]
# ## What is the average (mean, median, max, min) salary?

# %%
deduplicated["salary"].describe()
# Out:
# count        4,958.00
# mean     1,692,477.94
# std      3,243,005.10
# min              0.00
# 25%        300,000.00
# 50%        507,500.00
# 75%      1,300,000.00
# max     32,571,000.00
# Name: salary, dtype: float64

# %% [markdown]
# ## Who makes the most money?

# %%
max_salary = deduplicated["salary"].max()

# %%
deduplicated[deduplicated["salary"] == max_salary]
# Out:
#         playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 18735  kershcl01   1,988.00        3.00     19.00          USA         TX
#
#       birthCity  deathYear  deathMonth  deathDay deathCountry deathState  \
# 18735    Dallas        nan         nan       nan          NaN        NaN
#
#       deathCity nameFirst nameLast       nameGiven  weight  height bats  \
# 18735       NaN   Clayton  Kershaw  Clayton Edward  225.00   76.00    L
#
#       throws       debut   finalGame   retroID    bbrefID   yearID teamID  \
# 18735      L  2008-05-25  2015-10-04  kersc001  kershcl01 2,015.00    LAN
#
#       lgID        salary
# 18735   NL 32,571,000.00

# %% [markdown]
# ## What are the most common baseball players salaries?

# %% [markdown]
# Draw a histogram. <br>
# *([documentation reference](http://agate.readthedocs.io/en/1.5.5/cookbook/charting.html?highlight=pivot))*

# %%
deduplicated.hist("salary")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff639cfd470>]], dtype=object)

# %% [markdown]
# We can do the same with the column `yearID` to see how recent our data is.<br>
# We have 30 years in our data set, so we need to do some minor tweaking

# %%
deduplicated.hist("yearID", bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff639c2ab38>]], dtype=object)

# %% [markdown]
# ## Who are the top 10% highest-paid players?

# %% [markdown]
# calculate the 90 percentile cutoff

# %%
top_10_p = deduplicated["salary"].quantile(q=0.9)

# %% [markdown]
# filter out players that make more money than the cutoff

# %%
best_paid = deduplicated[deduplicated["salary"] >= top_10_p]

# %% [markdown]
# use the `nlargest` to see the top 10 best paid players

# %%
best_paid_top_10 = best_paid.nlargest(10, "salary")
best_paid_top_10
# Out:
#         playerID  birthYear  birthMonth  birthDay birthCountry  \
# 18735  kershcl01   1,988.00        3.00     19.00          USA
# 36569  verlaju01   1,983.00        2.00     20.00          USA
# 13538  greinza01   1,983.00       10.00     21.00          USA
# 16479  howarry01   1,979.00       11.00     19.00          USA
# 20087    leecl02   1,978.00        8.00     30.00          USA
# 13538  greinza01   1,983.00       10.00     21.00          USA
# 16479  howarry01   1,979.00       11.00     19.00          USA
# 20087    leecl02   1,978.00        8.00     30.00          USA
# 13538  greinza01   1,983.00       10.00     21.00          USA
# 16479  howarry01   1,979.00       11.00     19.00          USA
# 20087    leecl02   1,978.00        8.00     30.00          USA
# 15555  hernafe02   1,986.00        4.00      8.00    Venezuela
# 37613  wellsve01   1,978.00       12.00      8.00          USA
# 5384    canoro01   1,982.00       10.00     22.00         D.R.
# 10823  fieldpr01   1,984.00        5.00      9.00          USA
# 28702  pujolal01   1,980.00        1.00     16.00         D.R.
# 5384    canoro01   1,982.00       10.00     22.00         D.R.
# 10823  fieldpr01   1,984.00        5.00      9.00          USA
# 28702  pujolal01   1,980.00        1.00     16.00         D.R.
# 5384    canoro01   1,982.00       10.00     22.00         D.R.
# 10823  fieldpr01   1,984.00        5.00      9.00          USA
# 28702  pujolal01   1,980.00        1.00     16.00         D.R.
#
#                  birthState             birthCity  deathYear  deathMonth  \
# 18735                    TX                Dallas        nan         nan
# 36569                    VA         Manakin Sabot        nan         nan
# 13538                    FL               Orlando        nan         nan
# 16479                    MO             St. Louis        nan         nan
# 20087                    AR                Benton        nan         nan
# 13538                    FL               Orlando        nan         nan
# 16479                    MO             St. Louis        nan         nan
# 20087                    AR                Benton        nan         nan
# 13538                    FL               Orlando        nan         nan
# 16479                    MO             St. Louis        nan         nan
# 20087                    AR                Benton        nan         nan
# 15555              Carabobo              Valencia        nan         nan
# 37613                    LA            Shreveport        nan         nan
# 5384   San Pedro de Macoris  San Pedro de Macoris        nan         nan
# 10823                    CA               Ontario        nan         nan
# 28702     Distrito Nacional         Santo Domingo        nan         nan
# 5384   San Pedro de Macoris  San Pedro de Macoris        nan         nan
# 10823                    CA               Ontario        nan         nan
# 28702     Distrito Nacional         Santo Domingo        nan         nan
# 5384   San Pedro de Macoris  San Pedro de Macoris        nan         nan
# 10823                    CA               Ontario        nan         nan
# 28702     Distrito Nacional         Santo Domingo        nan         nan
#
#        deathDay deathCountry deathState deathCity nameFirst   nameLast  \
# 18735       nan          NaN        NaN       NaN   Clayton    Kershaw
# 36569       nan          NaN        NaN       NaN    Justin  Verlander
# 13538       nan          NaN        NaN       NaN      Zack    Greinke
# 16479       nan          NaN        NaN       NaN      Ryan     Howard
# 20087       nan          NaN        NaN       NaN     Cliff        Lee
# 13538       nan          NaN        NaN       NaN      Zack    Greinke
# 16479       nan          NaN        NaN       NaN      Ryan     Howard
# 20087       nan          NaN        NaN       NaN     Cliff        Lee
# 13538       nan          NaN        NaN       NaN      Zack    Greinke
# 16479       nan          NaN        NaN       NaN      Ryan     Howard
# 20087       nan          NaN        NaN       NaN     Cliff        Lee
# 15555       nan          NaN        NaN       NaN     Felix  Hernandez
# 37613       nan          NaN        NaN       NaN    Vernon      Wells
# 5384        nan          NaN        NaN       NaN  Robinson       Cano
# 10823       nan          NaN        NaN       NaN    Prince    Fielder
# 28702       nan          NaN        NaN       NaN    Albert     Pujols
# 5384        nan          NaN        NaN       NaN  Robinson       Cano
# 10823       nan          NaN        NaN       NaN    Prince    Fielder
# 28702       nan          NaN        NaN       NaN    Albert     Pujols
# 5384        nan          NaN        NaN       NaN  Robinson       Cano
# 10823       nan          NaN        NaN       NaN    Prince    Fielder
# 28702       nan          NaN        NaN       NaN    Albert     Pujols
#
#             nameGiven  weight  height bats throws       debut   finalGame  \
# 18735  Clayton Edward  225.00   76.00    L      L  2008-05-25  2015-10-04
# 36569   Justin Brooks  225.00   77.00    R      R  2005-07-04  2015-10-03
# 13538  Donald Zachary  195.00   72.00    R      R  2004-05-22  2015-10-03
# 16479      Ryan James  250.00   76.00    L      L  2004-09-01  2015-09-14
# 20087  Clifton Phifer  205.00   75.00    L      L  2002-09-15  2014-07-31
# 13538  Donald Zachary  195.00   72.00    R      R  2004-05-22  2015-10-03
# 16479      Ryan James  250.00   76.00    L      L  2004-09-01  2015-09-14
# 20087  Clifton Phifer  205.00   75.00    L      L  2002-09-15  2014-07-31
# 13538  Donald Zachary  195.00   72.00    R      R  2004-05-22  2015-10-03
# 16479      Ryan James  250.00   76.00    L      L  2004-09-01  2015-09-14
# 20087  Clifton Phifer  205.00   75.00    L      L  2002-09-15  2014-07-31
# 15555   Felix Abraham  225.00   75.00    R      R  2005-08-04  2015-09-26
# 37613       Vernon M.  230.00   73.00    R      R  1999-08-30  2013-09-29
# 5384    Robinson Jose  210.00   72.00    L      R  2005-05-03  2015-10-04
# 10823   Prince Semien  275.00   71.00    L      R  2005-06-13  2015-10-04
# 28702    Jose Alberto  230.00   75.00    R      R  2001-04-02  2015-10-04
# 5384    Robinson Jose  210.00   72.00    L      R  2005-05-03  2015-10-04
# 10823   Prince Semien  275.00   71.00    L      R  2005-06-13  2015-10-04
# 28702    Jose Alberto  230.00   75.00    R      R  2001-04-02  2015-10-04
# 5384    Robinson Jose  210.00   72.00    L      R  2005-05-03  2015-10-04
# 10823   Prince Semien  275.00   71.00    L      R  2005-06-13  2015-10-04
# 28702    Jose Alberto  230.00   75.00    R      R  2001-04-02  2015-10-04
#
#         retroID    bbrefID   yearID teamID lgID        salary
# 18735  kersc001  kershcl01 2,015.00    LAN   NL 32,571,000.00
# 36569  verlj001  verlaju01 2,015.00    DET   AL 28,000,000.00
# 13538  greiz001  greinza01 2,015.00    LAN   NL 25,000,000.00
# 16479  howar001  howarry01 2,015.00    PHI   NL 25,000,000.00
# 20087  lee-c003    leecl02 2,014.00    PHI   NL 25,000,000.00
# 13538  greiz001  greinza01 2,015.00    LAN   NL 25,000,000.00
# 16479  howar001  howarry01 2,015.00    PHI   NL 25,000,000.00
# 20087  lee-c003    leecl02 2,014.00    PHI   NL 25,000,000.00
# 13538  greiz001  greinza01 2,015.00    LAN   NL 25,000,000.00
# 16479  howar001  howarry01 2,015.00    PHI   NL 25,000,000.00
# 20087  lee-c003    leecl02 2,014.00    PHI   NL 25,000,000.00
# 15555  hernf002  hernafe02 2,015.00    SEA   AL 24,857,000.00
# 37613  wellv001  wellsve01 2,013.00    NYA   AL 24,642,857.00
# 5384   canor001   canoro01 2,015.00    SEA   AL 24,000,000.00
# 10823  fielp001  fieldpr01 2,015.00    TEX   AL 24,000,000.00
# 28702  pujoa001  pujolal01 2,015.00    LAA   AL 24,000,000.00
# 5384   canor001   canoro01 2,015.00    SEA   AL 24,000,000.00
# 10823  fielp001  fieldpr01 2,015.00    TEX   AL 24,000,000.00
# 28702  pujoa001  pujolal01 2,015.00    LAA   AL 24,000,000.00
# 5384   canor001   canoro01 2,015.00    SEA   AL 24,000,000.00
# 10823  fielp001  fieldpr01 2,015.00    TEX   AL 24,000,000.00
# 28702  pujoa001  pujolal01 2,015.00    LAA   AL 24,000,000.00

# %% [markdown]
# draw a chart

# %%
best_paid_top_10.plot(kind="bar", x="nameLast", y="salary")

# %% [markdown]
# save the data

# %%
best_paid.to_csv('highest-paid.csv')
